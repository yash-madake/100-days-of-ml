# %% [markdown]
# <a href="https://colab.research.google.com/github/yash-madake/100-days-of-ml/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

print('Pandas library installed and imported successfully!')
# Out:
# Pandas library installed and imported successfully!

# %%
pip install numpy

# %%
import numpy as np

print('Numpy library installed and imported successfully!')
# Out:
# Numpy library installed and imported successfully!

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

print('Matplotlib library installed and imported successfully!')
# Out:
# Matplotlib library installed and imported successfully!
